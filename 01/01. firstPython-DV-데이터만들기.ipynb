# %% [markdown]
# # Data Visualization - 나의첫파이썬 15장 - 데이터 만들기

# %% [markdown]
# ## 15.2 단순한 그래프 그리기

# %% [markdown]
# - mpl_squares.py

# %%
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]
plt.plot(squares)
plt.show()

# %% [markdown]
# ### 15.2.1 레이블과 그래프 두께 바꾸기

# %%
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]
plt.style.use(['dark_background'])
plt.plot(squares, linewidth=5)
plt.title("Square Number", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.xlabel("Square of Value", fontsize=14)
plt.tick_params(axis='both', labelsize=14)
plt.show()

# %% [markdown]
# ### 15.2.2 그래프 수정하기

# %%
import matplotlib.pyplot as plt

input_values = [1, 2, 3, 4, 5] 
squares = [1, 4, 9, 16, 25]
plt.style.use(['dark_background'])
plt.plot(input_values, squares, linewidth=5)
plt.title("Square Number", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.xlabel("Square of Value", fontsize=14)
plt.tick_params(axis='both', labelsize=14)
plt.show()

# %% [markdown]
# ### 15.2.3 scatter()로 점 그리기

# %% [markdown]
# - scatter_squares.py

# %%
plt.scatter(2, 4)
plt.show()

# %%
plt.scatter(2, 4, s=200)
plt.title("Square Number", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.xlabel("Square of Value", fontsize=14)
plt.tick_params(axis='both', which="major", labelsize=14)
plt.show()

# %% [markdown]
# ### 15.2.4 scatter()로 점 여러 개 그리기

# %%
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.scatter(x_values, y_values, s=100)
plt.title("Square Number", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.xlabel("Square of Value", fontsize=14)
plt.tick_params(axis='both', which="major", labelsize=14)
plt.show()

# %% [markdown]
# ### 15.2.5 데이터를 자동으로 계산하기

# %%
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]

plt.scatter(x_values, y_values, s=5)
plt.title("Square Number", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.xlabel("Square of Value", fontsize=14)
plt.tick_params(axis='both', which="major", labelsize=14)
# plt.axis([0, 1100, 0, 1100000]) #각 축의 범위 지정
plt.show()

# %% [markdown]
# ### 15.2.6 점에서 외곽선 제거하기

# %% [markdown]
# - edgecolor='none'

# %%
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]

#plt.style.use(['Solarize_Light2'])
#plt.style.use(['ggplot'])
plt.style.use(['dark_background'])
plt.scatter(x_values, y_values, c='red', edgecolor='none', s=40)
#plt.scatter(x_values, y_values, c=(0, 0, 0.8), edgecolor='none', s=40) # RGB

plt.title("Square Number", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.xlabel("Square of Value", fontsize=14)
plt.tick_params(axis='both', which="major", labelsize=14)
plt.axis([0, 1100, 0, 1100000]) #각 축의 범위 지정
plt.show()

# %% [markdown]
# ### 15.2.8 컬러맵 사용하기

# %%
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]


plt.style.use(['dark_background'])
#plt.style.use(['ggplot'])
plt.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, edgecolor='none', s=40)

plt.title("Square Number", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.xlabel("Square of Value", fontsize=14)
plt.tick_params(axis='both', which="major", labelsize=14)
plt.axis([0, 1100, 0, 1100000]) #각 축의 범위 지정
plt.show()

# %% [markdown]
# ### 15.2.9 자동으로 그래프 저장하기

# %%
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]


plt.style.use(['dark_background'])
#plt.style.use(['ggplot'])
plt.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, edgecolor='none', s=40)

plt.title("Square Number", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.xlabel("Square of Value", fontsize=14)
plt.tick_params(axis='both', which="major", labelsize=14)
plt.axis([0, 1100, 0, 1100000]) #각 축의 범위 지정

plt.savefig('squares_plot.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 15.3 Random Walk

# %% [markdown]
# ### 15.3.1 RandomWalk()클래스 만들기

# %% [markdown]
# - random_walk.py

# %%
from random import choice

class RandomWalk():
    def __init__(self, num_points=5000):
        self.num_points = num_points
        
        self.x_values = [0]
        self.y_values = [0]
    
    def fill_walk(self):
        while len(self.x_values) < self.num_points:
            x_direction = choice([1, -1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance
            y_direction = choice([1, -1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance
            
            if x_step == 0 and y_step == 0:
                continue
            
            next_x = self.x_values[-1] + x_step
            next_y = self.y_values[-1] + y_step
            
            self.x_values.append(next_x)
            self.y_values.append(next_y)

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk
plt.style.use(['dark_background'])

rw = RandomWalk()
rw.fill_walk()

plt.scatter(rw.x_values, rw.y_values, s=15)
plt.show()

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk
plt.style.use(['dark_background'])

while True:
    rw = RandomWalk()
    rw.fill_walk()

    plt.scatter(rw.x_values, rw.y_values, s=15)
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): y
# Make another walk? (y/n): y
# Make another walk? (y/n): n

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk
plt.style.use(['dark_background'])

while True:
    rw = RandomWalk()
    rw.fill_walk()

    point_numbers = list(range(rw.num_points))
    plt.scatter(rw.x_values, rw.y_values, c=point_numbers, 
                cmap=plt.cm.Blues, edgecolor='none', s=15)
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): y
# Make another walk? (y/n): y
# Make another walk? (y/n): n

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk
plt.style.use(['dark_background'])

while True:
    rw = RandomWalk()
    rw.fill_walk()

    point_numbers = list(range(rw.num_points))
    plt.scatter(rw.x_values, rw.y_values, c=point_numbers, 
                cmap=plt.cm.Blues, edgecolor='none', s=15)
    
    # 시작과 끝점 강조
    plt.scatter(0, 0, c='green', edgecolor='none', s=100)
    plt.scatter(rw.x_values[-1], rw.y_values[-1], c='red',
                edgecolor='none', s=100)
    
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): y
# Make another walk? (y/n): n

# %% [markdown]
# - 축 없애기

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk
plt.style.use(['dark_background'])

while True:
    rw = RandomWalk()
    rw.fill_walk()

    point_numbers = list(range(rw.num_points))
    plt.scatter(rw.x_values, rw.y_values, c=point_numbers, 
                cmap=plt.cm.Blues, edgecolor='none', s=15)
    
    # 축 없애기
    plt.axes().get_xaxis().set_visible(False)
    plt.axes().get_yaxis().set_visible(False)
    
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# /Users/zetta/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /Users/zetta/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app
# Make another walk? (y/n): y
# Make another walk? (y/n): n

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk
plt.style.use(['dark_background'])

while True:
    rw = RandomWalk(50000)
    rw.fill_walk()

    point_numbers = list(range(rw.num_points))
    plt.scatter(rw.x_values, rw.y_values, c=point_numbers, 
                cmap=plt.cm.Blues, edgecolor='none', s=1)
    
    # 시작과 끝점 강조
    plt.scatter(0, 0, c='green', edgecolor='none', s=100)
    plt.scatter(rw.x_values[-1], rw.y_values[-1], c='red',
                edgecolor='none', s=100)
    
    # 축 없애기
    plt.axes().get_xaxis().set_visible(False)
    plt.axes().get_yaxis().set_visible(False)
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
# Out:
# /Users/zetta/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /Users/zetta/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Make another walk? (y/n): y
# Make another walk? (y/n): y
# Make another walk? (y/n): n

# %% [markdown]
# - 전체 화면에 표시

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk
plt.style.use(['dark_background'])

while True:
    rw = RandomWalk(50000)
    rw.fill_walk()
    
    #plt.figure(figsize=(10, 6))
    
    point_numbers = list(range(rw.num_points))
    plt.scatter(rw.x_values, rw.y_values, c=point_numbers, 
                cmap=plt.cm.Blues, edgecolor='none', s=1)
    
    # 시작과 끝점 강조
    plt.scatter(0, 0, c='green', edgecolor='none', s=100)
    plt.scatter(rw.x_values[-1], rw.y_values[-1], c='red',
                edgecolor='none', s=100)
    
    # 축 없애기
    plt.axes().get_xaxis().set_visible(False)
    plt.axes().get_yaxis().set_visible(False)
    plt.show()
    
    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break

# %% [markdown]
# ## 15.4 파이갤로 주사위 굴리기

# %% [markdown]
# ### 15.4.3 Die 클래스 만들기

# %% [markdown]
# - die.py

# %%
from random import radint

class die():
    def __init__(self, num_sides=6):
        self.num_sides = num_sides
        
    def roll(self):
        return radint(1, self.num_sides)

# %% [markdown]
# - die_visual.py

# %%
from die import Die

die = Die()
results = []
for roll_num in range(100):
    result = die.roll()
    results.append(result)
    
print(results)
# Out:
# [6, 3, 2, 5, 3, 6, 3, 3, 2, 6, 2, 6, 4, 3, 2, 5, 4, 6, 5, 1, 6, 5, 3, 6, 1, 1, 3, 3, 3, 2, 5, 1, 5, 2, 5, 3, 3, 6, 1, 4, 5, 4, 1, 3, 6, 1, 5, 4, 1, 4, 1, 6, 4, 6, 2, 6, 6, 2, 1, 1, 1, 5, 2, 6, 2, 5, 2, 1, 1, 5, 1, 2, 3, 6, 6, 4, 2, 5, 4, 5, 5, 1, 5, 1, 4, 2, 2, 6, 4, 5, 3, 6, 6, 6, 5, 2, 1, 4, 6, 6]

# %% [markdown]
# ### 15.4.5 결과 분석하기

# %%
from die import Die

die = Die()
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)
    
# 결과 분석
frequncies = []
for value  in range(1, die.num_sides+1):
    frequency = results.count(value)
    frequncies.append(frequency)

print(frequncies)
# Out:
# [180, 164, 181, 151, 172, 152]

# %% [markdown]
# ### 15.4.6 히스토그램 만들기

# %%
import pygal
from die import Die

die = Die()
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)

frequncies = []
for value  in range(1, die.num_sides+1):
    frequency = results.count(value)
    frequncies.append(frequency)
    
hist = pygal.Bar()
hist.title = "Result of rollong one D6 1000 times"
hist.x_labels = ['1', '2', '3', '4', '5', '6']
hist.x_title = "Result"
hist.y_title = "Frequency of Result"

hist.add('D6', frequncies)
hist.render_to_file('die_visual.svg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-14006ebd1e09> in <module>
# ----> 1 import pygal
#       2 from die import Die
#       3
#       4 die = Die()
#       5 results = []
#
# ModuleNotFoundError: No module named 'pygal'

# %%
from IPython.display import SVG
def display_svg(svg_code):
    return SVG(svg_code)

import pygal 
worldmap_chart = pygal.maps.world.World()
worldmap_chart.title = 'Some countries'
worldmap_chart.add('F countries', ['fr', 'fi'])
worldmap_chart.add('M countries', ['ma', 'mc', 'md', 'me', 'mg',
                                    'mk', 'ml', 'mm', 'mn', 'mo',
                                    'mr', 'mt', 'mu', 'mv', 'mw',
                                    'mx', 'my', 'mz'])
worldmap_chart.add('U countries', ['ua', 'ug', 'us', 'uy', 'uz'])
svg_code = worldmap_chart.render()

display_svg(svg_code)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-5ec6dca958e8> in <module>
#       3     return SVG(svg_code)
#       4
# ----> 5 import pygal
#       6 worldmap_chart = pygal.maps.world.World()
#       7 worldmap_chart.title = 'Some countries'
#
# ModuleNotFoundError: No module named 'pygal'
